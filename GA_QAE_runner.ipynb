# %%
import scipy as sp
from pennylane import numpy as np
from sklearn.preprocessing import MinMaxScaler

from GA_Manager import backend

# %%
events = np.load('10k_dijet.npy', requires_grad=False)
scaler = MinMaxScaler(feature_range=(0, sp.pi))
events = scaler.fit_transform(events)

# %%
rng_seed = None
rng = np.random.default_rng(seed=rng_seed)

config = {
    'backend_type': 'high',
    'n_qubits': 3,
    'n_moments': 4,
    'gates_arr': ['I', 'RX', 'RY', 'RZ', 'CNOT'],
    'gates_probs': [0.175, 0.175, 0.175, 0.175, 0.3],
    'pop_size': 52,
    'init_pop_size': 1000,
    'n_winners': 26,
    'n_mutations': 2,
    'n_mate_swaps': 1,
    'n_steps': 15,
    'latent_qubits': 1,
    'n_shots': 5,
    'seed': rng_seed,
    'events': events,
    'train_size': 10,
}

ga = backend(config)
# Out:
# Initial generation/selection in 14.92 seconds

# %%
ga.evolve()
# Out:
# GA iteration 0
# QML Optimization in 404.96 seconds
# !! IMPROVED PERFORMANCE !!
# Best Fitness: 1.464864864864865, Best ansatz: [{0: 'I', 1: 'RX', 2: 'RX'}, {0: 'RY', 1: 'RY', 2: 'RZ'}, {0: 'RZ', 1: 'CNOT_C-2', 2: 'CNOT_T-1'}, {0: 'RZ', 1: 'CNOT_C-2', 2: 'CNOT_T-1'}]
# GA iteration 2
# QML Optimization in 392.36 seconds
# Best Fitness: 1.464864864864865, Best ansatz: [{0: 'I', 1: 'RX', 2: 'RX'}, {0: 'RY', 1: 'RY', 2: 'RZ'}, {0: 'RZ', 1: 'CNOT_C-2', 2: 'CNOT_T-1'}, {0: 'RZ', 1: 'CNOT_C-2', 2: 'CNOT_T-1'}]
# GA iteration 3
# QML Optimization in 1787.03 seconds
# Best Fitness: 1.464864864864865, Best ansatz: [{0: 'I', 1: 'RX', 2: 'RX'}, {0: 'RY', 1: 'RY', 2: 'RZ'}, {0: 'RZ', 1: 'CNOT_C-2', 2: 'CNOT_T-1'}, {0: 'RZ', 1: 'CNOT_C-2', 2: 'CNOT_T-1'}]
# GA iteration 4
# Process SpawnPoolWorker-252:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-237:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-244:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-221:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-218:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-253:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-245:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-220:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/optimize/gradient_descent.py", line 117, in compute_grad
#     grad = g(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 115, in __call__
#     grad_value, ans = grad_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 141, in _grad_with_forward
#     grad_value = vjp(vspace(ans).ones())
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 14, in vjp
#     def vjp(g): return backward_pass(g, end_node)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 21, in backward_pass
#     ingrads = node.vjp(outgrad[0])
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 67, in <lambda>
#     return lambda g: (vjp(g),)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/autograd.py", line 198, in grad_fn
#     vjps = processing_fn(execute_fn(vjp_tapes)[0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 172, in wrapper
#     res = fn(execution_tapes.values(), **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 96, in fn
#     tapes = [expand_fn(tape) for tape in tapes]
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 96, in <listcomp>
#     tapes = [expand_fn(tape) for tape in tapes]
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 325, in <lambda>
#     expand_fn = lambda tape: device.expand_fn(tape, max_expansion=max_expansion)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_device.py", line 680, in expand_fn
#     return self.default_expand_fn(circuit, max_expansion=max_expansion)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_device.py", line 652, in default_expand_fn
#     ops_not_supported = not all(self.stopping_condition(op) for op in circuit.operations)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_device.py", line 652, in <genexpr>
#     ops_not_supported = not all(self.stopping_condition(op) for op in circuit.operations)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/boolean_fn.py", line 94, in __call__
#     return self.fn(obj)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_device.py", line 591, in <lambda>
#     lambda obj: not isinstance(obj, qml.tape.QuantumTape)
# KeyboardInterrupt
# Process SpawnPoolWorker-224:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/optimize/gradient_descent.py", line 117, in compute_grad
#     grad = g(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 115, in __call__
#     grad_value, ans = grad_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 141, in _grad_with_forward
#     grad_value = vjp(vspace(ans).ones())
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 14, in vjp
#     def vjp(g): return backward_pass(g, end_node)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 21, in backward_pass
#     ingrads = node.vjp(outgrad[0])
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 67, in <lambda>
#     return lambda g: (vjp(g),)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/autograd.py", line 198, in grad_fn
#     vjps = processing_fn(execute_fn(vjp_tapes)[0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/gradients/vjp.py", line 333, in processing_fn
#     vjp_ = processing_fns[t_idx](res_t, num=nums[t_idx])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/gradients/vjp.py", line 186, in processing_fn
#     jac = fn(results)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/gradients/parameter_shift.py", line 267, in processing_fn
#     g = qml.math.tensordot(res, qml.math.convert_like(gradient_coeffs[i], res), [[0], [0]])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 178, in wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 394, in tensordot
#     return np.tensordot(tensor1, tensor2, axes=axes, like=like)
#   File "/usr/local/lib/python3.8/site-packages/autoray/autoray.py", line 648, in __getattribute__
#     submod = object.__getattribute__(self, "submodule")
# KeyboardInterrupt
# Process SpawnPoolWorker-239:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-247:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-223:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 102, in train
#     fub_stud = qml.metric_tensor(config['qnode'], approx="block-diag")(theta, event=event_batch[i], config=config)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/metric_tensor.py", line 360, in wrapper
#     cjac = cjac_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 328, in _jacobian_function
#     jac = tuple(_jacobian(func, arg)(*args, **kwargs) for arg in _argnum)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 328, in <genexpr>
#     jac = tuple(_jacobian(func, arg)(*args, **kwargs) for arg in _argnum)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/differential_operators.py", line 61, in jacobian
#     return np.reshape(np.stack(grads), jacobian_shape)
#   File "/usr/local/lib/python3.8/site-packages/autograd/numpy/numpy_wrapper.py", line 88, in stack
#     arrays = [array(arr) for arr in arrays]
#   File "/usr/local/lib/python3.8/site-packages/autograd/numpy/numpy_wrapper.py", line 88, in <listcomp>
#     arrays = [array(arr) for arr in arrays]
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 14, in vjp
#     def vjp(g): return backward_pass(g, end_node)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 19, in backward_pass
#     for node in toposort(end_node):
#   File "/usr/local/lib/python3.8/site-packages/autograd/util.py", line 24, in toposort
#     node = stack.pop()
# KeyboardInterrupt
# Process SpawnPoolWorker-216:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-236:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 356, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib64/python3.8/multiprocessing/connection.py", line 220, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib64/python3.8/multiprocessing/connection.py", line 418, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib64/python3.8/multiprocessing/connection.py", line 383, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Process SpawnPoolWorker-251:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 102, in train
#     fub_stud = qml.metric_tensor(config['qnode'], approx="block-diag")(theta, event=event_batch[i], config=config)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/metric_tensor.py", line 335, in wrapper
#     mt = mt_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/batch_transform.py", line 313, in _wrapper
#     return processing_fn(res)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/metric_tensor.py", line 430, in processing_fn
#     g = scale * qml.math.cov_matrix(prob, obs, wires=tape.wires, diag_approx=diag_approx)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/quantum.py", line 125, in cov_matrix
#     p2 = marginal_prob(prob, o2wires)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/quantum.py", line 170, in marginal_prob
#     prob = np.sum(prob, axis=inactive_wires)
#   File "/usr/local/lib/python3.8/site-packages/autoray/autoray.py", line 85, in do
#     return get_lib_fn(backend, fn)(*args, **kwargs)
#   File "<__array_function__ internals>", line 5, in sum
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/fromnumeric.py", line 2259, in sum
#     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/fromnumeric.py", line 84, in _wrapreduction
#     return reduction(axis=axis, out=out, **passkwargs)
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/_methods.py", line 48, in _sum
#     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# KeyboardInterrupt
# Process SpawnPoolWorker-213:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-212:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-211:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib64/python3.8/multiprocessing/queues.py", line 355, in get
#     with self._rlock:
#   File "/usr/lib64/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Process SpawnPoolWorker-214:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 102, in train
#     fub_stud = qml.metric_tensor(config['qnode'], approx="block-diag")(theta, event=event_batch[i], config=config)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/metric_tensor.py", line 362, in wrapper
#     return _contract_metric_tensor_with_cjac(mt, cjac)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/metric_tensor.py", line 297, in _contract_metric_tensor_with_cjac
#     mt = qml.math.tensordot(cjac, qml.math.tensordot(mt, cjac, axes=[[-1], [0]]), axes=[[0], [0]])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 178, in wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 394, in tensordot
#     return np.tensordot(tensor1, tensor2, axes=axes, like=like)
#   File "/usr/local/lib/python3.8/site-packages/autoray/autoray.py", line 85, in do
#     return get_lib_fn(backend, fn)(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/wrapper.py", line 117, in _wrapped
#     res = obj(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/tracer.py", line 48, in f_wrapped
#     return f_raw(*args, **kwargs)
#   File "<__array_function__ internals>", line 5, in tensordot
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/numeric.py", line 1132, in tensordot
#     res = dot(at, bt)
#   File "<__array_function__ internals>", line 5, in dot
# KeyboardInterrupt
# Process SpawnPoolWorker-240:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 102, in train
#     fub_stud = qml.metric_tensor(config['qnode'], approx="block-diag")(theta, event=event_batch[i], config=config)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/metric_tensor.py", line 362, in wrapper
#     return _contract_metric_tensor_with_cjac(mt, cjac)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/metric_tensor.py", line 297, in _contract_metric_tensor_with_cjac
#     mt = qml.math.tensordot(cjac, qml.math.tensordot(mt, cjac, axes=[[-1], [0]]), axes=[[0], [0]])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 178, in wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 394, in tensordot
#     return np.tensordot(tensor1, tensor2, axes=axes, like=like)
#   File "/usr/local/lib/python3.8/site-packages/autoray/autoray.py", line 85, in do
#     return get_lib_fn(backend, fn)(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/wrapper.py", line 117, in _wrapped
#     res = obj(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/tracer.py", line 48, in f_wrapped
#     return f_raw(*args, **kwargs)
#   File "<__array_function__ internals>", line 5, in tensordot
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/numeric.py", line 1132, in tensordot
#     res = dot(at, bt)
#   File "<__array_function__ internals>", line 5, in dot
# KeyboardInterrupt
# Process SpawnPoolWorker-217:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/wrapper.py", line 117, in _wrapped
#     res = obj(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/tracer.py", line 48, in f_wrapped
#     return f_raw(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/tensor.py", line 155, in __array_ufunc__
#     res = super().__array_ufunc__(ufunc, method, *args, **kwargs)
# KeyboardInterrupt
# Process SpawnPoolWorker-222:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/optimize/gradient_descent.py", line 117, in compute_grad
#     grad = g(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 115, in __call__
#     grad_value, ans = grad_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 141, in _grad_with_forward
#     grad_value = vjp(vspace(ans).ones())
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 14, in vjp
#     def vjp(g): return backward_pass(g, end_node)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 21, in backward_pass
#     ingrads = node.vjp(outgrad[0])
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 67, in <lambda>
#     return lambda g: (vjp(g),)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/autograd.py", line 198, in grad_fn
#     vjps = processing_fn(execute_fn(vjp_tapes)[0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/gradients/vjp.py", line 333, in processing_fn
#     vjp_ = processing_fns[t_idx](res_t, num=nums[t_idx])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/gradients/vjp.py", line 186, in processing_fn
#     jac = fn(results)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/gradients/parameter_shift.py", line 267, in processing_fn
#     g = qml.math.tensordot(res, qml.math.convert_like(gradient_coeffs[i], res), [[0], [0]])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 178, in wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 394, in tensordot
#     return np.tensordot(tensor1, tensor2, axes=axes, like=like)
#   File "/usr/local/lib/python3.8/site-packages/autoray/autoray.py", line 85, in do
#     return get_lib_fn(backend, fn)(*args, **kwargs)
#   File "<__array_function__ internals>", line 5, in tensordot
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/numeric.py", line 1119, in tensordot
#     newshape_a = (int(multiply.reduce([as_[ax] for ax in notin])), N2)
# KeyboardInterrupt
# Process SpawnPoolWorker-260:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/optimize/gradient_descent.py", line 117, in compute_grad
#     grad = g(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 115, in __call__
#     grad_value, ans = grad_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 141, in _grad_with_forward
#     grad_value = vjp(vspace(ans).ones())
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 14, in vjp
#     def vjp(g): return backward_pass(g, end_node)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 21, in backward_pass
#     ingrads = node.vjp(outgrad[0])
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 67, in <lambda>
#     return lambda g: (vjp(g),)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/autograd.py", line 198, in grad_fn
#     vjps = processing_fn(execute_fn(vjp_tapes)[0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 172, in wrapper
#     res = fn(execution_tapes.values(), **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 97, in fn
#     return original_fn(tapes, **kwargs)
#   File "/usr/lib64/python3.8/contextlib.py", line 75, in inner
#     return func(*args, **kwds)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_qubit_device.py", line 355, in batch_execute
#     res = self.execute(circuit)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_qubit_device.py", line 261, in execute
#     self._samples = self.generate_samples()
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_qubit_device.py", line 570, in generate_samples
#     samples = self.sample_basis_states(number_of_states, rotated_prob)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_qubit_device.py", line 595, in sample_basis_states
#     return np.random.choice(basis_states, shots, p=state_probability)
#   File "mtrand.pyx", line 946, in numpy.random.mtrand.RandomState.choice
#   File "<__array_function__ internals>", line 2, in prod
# KeyboardInterrupt
# Process SpawnPoolWorker-233:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/wrapper.py", line 117, in _wrapped
#     res = obj(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/tracer.py", line 48, in f_wrapped
#     return f_raw(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/tensor.py", line 155, in __array_ufunc__
#     res = super().__array_ufunc__(ufunc, method, *args, **kwargs)
# KeyboardInterrupt
# Process SpawnPoolWorker-238:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/optimize/gradient_descent.py", line 117, in compute_grad
#     grad = g(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 115, in __call__
#     grad_value, ans = grad_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 141, in _grad_with_forward
#     grad_value = vjp(vspace(ans).ones())
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 14, in vjp
#     def vjp(g): return backward_pass(g, end_node)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 21, in backward_pass
#     ingrads = node.vjp(outgrad[0])
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 67, in <lambda>
#     return lambda g: (vjp(g),)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/autograd.py", line 198, in grad_fn
#     vjps = processing_fn(execute_fn(vjp_tapes)[0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 172, in wrapper
#     res = fn(execution_tapes.values(), **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 97, in fn
#     return original_fn(tapes, **kwargs)
#   File "/usr/lib64/python3.8/contextlib.py", line 75, in inner
#     return func(*args, **kwds)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_qubit_device.py", line 355, in batch_execute
#     res = self.execute(circuit)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_qubit_device.py", line 254, in execute
#     self.check_validity(circuit.operations, circuit.observables)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_device.py", line 931, in check_validity
#     operation_name = o.name
#   File "/usr/local/lib/python3.8/site-packages/pennylane/operation.py", line 1441, in name
#     return self._name + ".inv" if self.inverse else self._name
#   File "/usr/local/lib/python3.8/site-packages/pennylane/operation.py", line 1392, in inverse
#     return self._inverse
# KeyboardInterrupt
# Process SpawnPoolWorker-258:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/optimize/gradient_descent.py", line 117, in compute_grad
#     grad = g(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 115, in __call__
#     grad_value, ans = grad_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 141, in _grad_with_forward
#     grad_value = vjp(vspace(ans).ones())
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 14, in vjp
#     def vjp(g): return backward_pass(g, end_node)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 21, in backward_pass
#     ingrads = node.vjp(outgrad[0])
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 67, in <lambda>
#     return lambda g: (vjp(g),)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/autograd.py", line 198, in grad_fn
#     vjps = processing_fn(execute_fn(vjp_tapes)[0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 117, in wrapper
#     h = tape.hash
#   File "/usr/local/lib/python3.8/site-packages/pennylane/tape/tape.py", line 1574, in hash
#     fingerprint.extend(op.hash for op in self.operations)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/tape/tape.py", line 1574, in <genexpr>
#     fingerprint.extend(op.hash for op in self.operations)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/operation.py", line 534, in hash
#     _process_data(self),
#   File "/usr/local/lib/python3.8/site-packages/pennylane/operation.py", line 350, in _process_data
#     return str([qml.math.round(qml.math.real(d) % (2 * np.pi), 10) for d in op.data])
# KeyboardInterrupt
# Process SpawnPoolWorker-257:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/optimize/gradient_descent.py", line 117, in compute_grad
#     grad = g(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 115, in __call__
#     grad_value, ans = grad_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 133, in _grad_with_forward
#     vjp, ans = _make_vjp(fun, x)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 10, in make_vjp
#     end_value, end_node =  trace(start_node, fun, x)
#   File "/usr/local/lib/python3.8/site-packages/autograd/tracer.py", line 10, in trace
#     end_box = fun(start_box)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 15, in unary_f
#     return fun(*subargs, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/qnode.py", line 609, in __call__
#     self.construct(args, kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/qnode.py", line 526, in construct
#     self._qfunc_output = self.func(*args, **kwargs)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 68, in circuit
#     exec(m)
#   File "<string>", line 1, in <module>
#   File "/usr/local/lib/python3.8/site-packages/pennylane/templates/broadcast.py", line 561, in broadcast
#     wire_sequence, parameters = _preprocess(parameters, pattern, wires)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/templates/broadcast.py", line 124, in _preprocess
#     parameters = qml.math.expand_dims(parameters, 1)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/__init__.py", line 80, in __getattr__
#     return getattr(ar.numpy, name)
#   File "/usr/local/lib/python3.8/site-packages/autoray/autoray.py", line 653, in __getattribute__
#     try:
# KeyboardInterrupt
# Process SpawnPoolWorker-248:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/optimize/gradient_descent.py", line 117, in compute_grad
#     grad = g(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 115, in __call__
#     grad_value, ans = grad_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 141, in _grad_with_forward
#     grad_value = vjp(vspace(ans).ones())
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 14, in vjp
#     def vjp(g): return backward_pass(g, end_node)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 21, in backward_pass
#     ingrads = node.vjp(outgrad[0])
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 67, in <lambda>
#     return lambda g: (vjp(g),)
#   File "/usr/local/lib/python3.8/site-packages/autograd/numpy/numpy_vjps.py", line 701, in <lambda>
#     defvjp(func(ArrayBox.__getitem__), lambda ans, A, idx: lambda g: untake(g, idx, vspace(A)))
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 233, in vspace
#     return VSpace.mappings[type(value)](value)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/tensor.py", line 313, in <lambda>
#     VSpace.mappings[tensor] = lambda x: ComplexArrayVSpace(x) if onp.iscomplexobj(x) else ArrayVSpace(x)
#   File "/usr/local/lib/python3.8/site-packages/autograd/numpy/numpy_vspaces.py", line 7, in __init__
#     self.shape = value.shape
# KeyboardInterrupt
# Process SpawnPoolWorker-227:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 102, in train
#     fub_stud = qml.metric_tensor(config['qnode'], approx="block-diag")(theta, event=event_batch[i], config=config)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/metric_tensor.py", line 335, in wrapper
#     mt = mt_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/batch_transform.py", line 302, in _wrapper
#     res = qml.execute(
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 414, in execute
#     res = _execute(
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/autograd.py", line 66, in execute
#     return _execute(
#   File "/usr/local/lib/python3.8/site-packages/autograd/tracer.py", line 48, in f_wrapped
#     return f_raw(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/autograd.py", line 110, in _execute
#     res, jacs = execute_fn(tapes, **gradient_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 172, in wrapper
#     res = fn(execution_tapes.values(), **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 97, in fn
#     return original_fn(tapes, **kwargs)
#   File "/usr/lib64/python3.8/contextlib.py", line 75, in inner
#     return func(*args, **kwds)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_qubit_device.py", line 355, in batch_execute
#     res = self.execute(circuit)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_qubit_device.py", line 261, in execute
#     self._samples = self.generate_samples()
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_qubit_device.py", line 570, in generate_samples
#     samples = self.sample_basis_states(number_of_states, rotated_prob)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_qubit_device.py", line 595, in sample_basis_states
#     return np.random.choice(basis_states, shots, p=state_probability)
#   File "mtrand.pyx", line 946, in numpy.random.mtrand.RandomState.choice
#   File "<__array_function__ internals>", line 2, in prod
# KeyboardInterrupt
# Process SpawnPoolWorker-241:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
# ...
#     elif not all(stop_at(op) for op in tape.operations):
#   File "/usr/local/lib/python3.8/site-packages/pennylane/boolean_fn.py", line 94, in __call__
#     return self.fn(obj)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/boolean_fn.py", line 88, in <lambda>
#     return BooleanFn(lambda obj: self.fn(obj) or other.fn(obj))
#   File "/usr/local/lib/python3.8/site-packages/pennylane/boolean_fn.py", line 85, in <lambda>
#     return BooleanFn(lambda obj: self.fn(obj) and other.fn(obj))
#   File "/usr/local/lib/python3.8/site-packages/pennylane/operation.py", line 2467, in has_gen
#     obj.generator()
#   File "/usr/local/lib/python3.8/site-packages/pennylane/ops/qubit/parametric_ops.py", line 73, in generator
#     return -0.5 * PauliX(wires=self.wires)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/operation.py", line 1671, in __mul__
#     return qml.Hamiltonian([a], [self], simplify=True)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/ops/qubit/hamiltonian.py", line 204, in __init__
#     self.simplify()
#   File "/usr/local/lib/python3.8/site-packages/pennylane/ops/qubit/hamiltonian.py", line 397, in simplify
#     self._coeffs = qml.math.stack(new_coeffs) if new_coeffs else []
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 178, in wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 507, in stack
#     return np.stack(values, axis=axis, like=like)
#   File "/usr/local/lib/python3.8/site-packages/autoray/autoray.py", line 85, in do
#     return get_lib_fn(backend, fn)(*args, **kwargs)
#   File "<__array_function__ internals>", line 5, in stack
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/shape_base.py", line 432, in stack
#     expanded_arrays = [arr[sl] for arr in arrays]
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/shape_base.py", line 432, in <listcomp>
#     expanded_arrays = [arr[sl] for arr in arrays]
# KeyboardInterrupt
# Process SpawnPoolWorker-209:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/optimize/gradient_descent.py", line 117, in compute_grad
#     grad = g(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 115, in __call__
#     grad_value, ans = grad_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 141, in _grad_with_forward
#     grad_value = vjp(vspace(ans).ones())
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 14, in vjp
#     def vjp(g): return backward_pass(g, end_node)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 21, in backward_pass
#     ingrads = node.vjp(outgrad[0])
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 67, in <lambda>
#     return lambda g: (vjp(g),)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/autograd.py", line 198, in grad_fn
#     vjps = processing_fn(execute_fn(vjp_tapes)[0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 172, in wrapper
#     res = fn(execution_tapes.values(), **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 97, in fn
#     return original_fn(tapes, **kwargs)
#   File "/usr/lib64/python3.8/contextlib.py", line 75, in inner
#     return func(*args, **kwds)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_qubit_device.py", line 353, in batch_execute
#     self.reset()
#   File "/usr/local/lib/python3.8/site-packages/pennylane_qulacs/qulacs_device.py", line 372, in reset
#     self._pre_rotated_state = self._state.copy()
# KeyboardInterrupt
# Process SpawnPoolWorker-249:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/wrapper.py", line 117, in _wrapped
#     res = obj(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/tracer.py", line 48, in f_wrapped
#     return f_raw(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/tensor.py", line 155, in __array_ufunc__
#     res = super().__array_ufunc__(ufunc, method, *args, **kwargs)
# KeyboardInterrupt
# Process SpawnPoolWorker-226:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 102, in train
#     fub_stud = qml.metric_tensor(config['qnode'], approx="block-diag")(theta, event=event_batch[i], config=config)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/metric_tensor.py", line 360, in wrapper
#     cjac = cjac_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 328, in _jacobian_function
#     jac = tuple(_jacobian(func, arg)(*args, **kwargs) for arg in _argnum)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 328, in <genexpr>
#     jac = tuple(_jacobian(func, arg)(*args, **kwargs) for arg in _argnum)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/differential_operators.py", line 61, in jacobian
#     return np.reshape(np.stack(grads), jacobian_shape)
#   File "/usr/local/lib/python3.8/site-packages/autograd/numpy/numpy_wrapper.py", line 88, in stack
#     arrays = [array(arr) for arr in arrays]
#   File "/usr/local/lib/python3.8/site-packages/autograd/numpy/numpy_wrapper.py", line 88, in <listcomp>
#     arrays = [array(arr) for arr in arrays]
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 14, in vjp
#     def vjp(g): return backward_pass(g, end_node)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 21, in backward_pass
#     ingrads = node.vjp(outgrad[0])
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 67, in <lambda>
#     return lambda g: (vjp(g),)
#   File "/usr/local/lib/python3.8/site-packages/autograd/numpy/numpy_vjps.py", line 701, in <lambda>
#     defvjp(func(ArrayBox.__getitem__), lambda ans, A, idx: lambda g: untake(g, idx, vspace(A)))
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 233, in vspace
#     return VSpace.mappings[type(value)](value)
#   File "/usr/local/lib/python3.8/site-packages/autograd/numpy/numpy_vspaces.py", line 58, in <lambda>
#     if np.iscomplexobj(x)
#   File "<__array_function__ internals>", line 5, in iscomplexobj
#   File "/usr/local/lib64/python3.8/site-packages/numpy/lib/type_check.py", line 337, in iscomplexobj
#     dtype = x.dtype
# KeyboardInterrupt
# Process SpawnPoolWorker-235:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 102, in train
#     fub_stud = qml.metric_tensor(config['qnode'], approx="block-diag")(theta, event=event_batch[i], config=config)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/metric_tensor.py", line 362, in wrapper
#     return _contract_metric_tensor_with_cjac(mt, cjac)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/transforms/metric_tensor.py", line 297, in _contract_metric_tensor_with_cjac
#     mt = qml.math.tensordot(cjac, qml.math.tensordot(mt, cjac, axes=[[-1], [0]]), axes=[[0], [0]])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 178, in wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/math/multi_dispatch.py", line 394, in tensordot
#     return np.tensordot(tensor1, tensor2, axes=axes, like=like)
#   File "/usr/local/lib/python3.8/site-packages/autoray/autoray.py", line 85, in do
#     return get_lib_fn(backend, fn)(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/wrapper.py", line 117, in _wrapped
#     res = obj(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/tracer.py", line 48, in f_wrapped
#     return f_raw(*args, **kwargs)
#   File "<__array_function__ internals>", line 5, in tensordot
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/numeric.py", line 1132, in tensordot
#     res = dot(at, bt)
#   File "<__array_function__ internals>", line 5, in dot
# KeyboardInterrupt
# Process SpawnPoolWorker-219:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/wrapper.py", line 117, in _wrapped
#     res = obj(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/tracer.py", line 48, in f_wrapped
#     return f_raw(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/numpy/tensor.py", line 155, in __array_ufunc__
#     res = super().__array_ufunc__(ufunc, method, *args, **kwargs)
# KeyboardInterrupt
# Process SpawnPoolWorker-254:
# Traceback (most recent call last):
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib64/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib64/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 47, in main
#     best_fid = train(events, config)
#   File "/storage/af/user/tsievert/SFP22/qae.py", line 103, in train
#     grads[i] = np.matmul(fub_stud, opt.compute_grad(config['qnode'], (theta, event_batch[i], config), {})[0][0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/optimize/gradient_descent.py", line 117, in compute_grad
#     grad = g(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 115, in __call__
#     grad_value, ans = grad_fn(*args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/autograd/wrap_util.py", line 20, in nary_f
#     return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/_grad.py", line 141, in _grad_with_forward
#     grad_value = vjp(vspace(ans).ones())
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 14, in vjp
#     def vjp(g): return backward_pass(g, end_node)
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 21, in backward_pass
#     ingrads = node.vjp(outgrad[0])
#   File "/usr/local/lib/python3.8/site-packages/autograd/core.py", line 67, in <lambda>
#     return lambda g: (vjp(g),)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/autograd.py", line 198, in grad_fn
#     vjps = processing_fn(execute_fn(vjp_tapes)[0])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/interfaces/execution.py", line 117, in wrapper
#     h = tape.hash
#   File "/usr/local/lib/python3.8/site-packages/pennylane/tape/tape.py", line 1574, in hash
#     fingerprint.extend(op.hash for op in self.operations)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/tape/tape.py", line 1574, in <genexpr>
#     fingerprint.extend(op.hash for op in self.operations)
#   File "/usr/local/lib/python3.8/site-packages/pennylane/operation.py", line 534, in hash
#     _process_data(self),
#   File "/usr/local/lib/python3.8/site-packages/pennylane/operation.py", line 350, in _process_data
#     return str([qml.math.round(qml.math.real(d) % (2 * np.pi), 10) for d in op.data])
#   File "/usr/local/lib/python3.8/site-packages/pennylane/operation.py", line 350, in <listcomp>
#     return str([qml.math.round(qml.math.real(d) % (2 * np.pi), 10) for d in op.data])
#   File "/usr/local/lib/python3.8/site-packages/autoray/autoray.py", line 85, in do
#     return get_lib_fn(backend, fn)(*args, **kwargs)
#   File "<__array_function__ internals>", line 5, in round_
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/fromnumeric.py", line 3739, in round_
#     return around(a, decimals=decimals, out=out)
#   File "<__array_function__ internals>", line 5, in around
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/fromnumeric.py", line 3314, in around
#     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/fromnumeric.py", line 54, in _wrapfunc
#     return _wrapit(obj, method, *args, **kwds)
#   File "/usr/local/lib64/python3.8/site-packages/numpy/core/fromnumeric.py", line 43, in _wrapit
#     result = getattr(asarray(obj), method)(*args, **kwds)
# KeyboardInterrupt
